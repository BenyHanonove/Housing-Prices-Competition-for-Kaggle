# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load CSV file into a DataFrame
train_path = "../data/train_normalize.csv"
train_df = pd.read_csv(train_path)

# Ensure all columns are displayed
pd.set_option("display.max_columns", None)

# Display first few rows
train_df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60        60         65.0     8450       1      0       100
# 1   2          20        60         80.0     9600       1      0       100
# 2   3          60        60         68.0    11250       1      0        75
# 3   4          70        60         60.0     9550       1      0        75
# 4   5          60        60         84.0    14260       1      0        75
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0          100        100         60        100             6          60
# 1          100        100         40        100            25          50
# 2          100        100         60        100             6          60
# 3          100        100         80        100             7          60
# 4          100        100         40        100            16          60
#
# ...

# %%
# Plot the distribution of SalePrice
plt.figure(figsize=(10, 6))
sns.histplot(train_df["SalePrice"], bins=50, kde=True, color="blue")
plt.xlabel("Sale Price")
plt.ylabel("Frequency")
plt.title("Distribution of Sale Price")
plt.show()

# %%
# Count the number of houses with SalePrice above 500,000
num_houses_above_500k = (train_df['SalePrice'] > 500000).sum()

# Print the result
print(f"Number of houses with SalePrice above 500,000: {num_houses_above_500k}")
# Out:
# Number of houses with SalePrice above 500,000: 0

# %%
# Compute the correlation matrix with SalePrice
correlation_matrix = train_df.corr()

# Extract correlations of all features with SalePrice
saleprice_correlation = correlation_matrix[["SalePrice"]].sort_values(by="SalePrice", ascending=False)

# Plot heatmap
plt.figure(figsize=(8, 12))
sns.heatmap(saleprice_correlation, annot=True, cmap="coolwarm", fmt=".3f", linewidths=0.5)
plt.title("Feature Correlation with SalePrice")
plt.show()

# %%
# Scatter plot of GrLivArea vs SalePrice
plt.figure(figsize=(10, 6))
sns.scatterplot(data=train_df, x="GrLivArea", y="SalePrice", alpha=0.6)
plt.title("Living Area vs Sale Price")
plt.xlabel("Above Ground Living Area (sqft)")
plt.ylabel("Sale Price")
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(x="Neighborhood", y="SalePrice", data=train_df)
plt.xticks(rotation=90)
plt.title("Sale Price Distribution by Neighborhood")
plt.show()
